# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvarajsivaraman/assignment_01/blob/main/project_youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-api-python-client
# !pip install mysql-connector-python
# !pip install pymongo
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (2.84.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.27.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2024.2.2)
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.10/dist-packages (8.3.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.6.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.6.1)

# %%
import googleapiclient.discovery
api_key='AIzaSyA_V9FqIHH_D_ZtOU-YKnG-NEbPVcWiWRI'
api_service_name = "youtube"
api_version ="v3"

# %%
youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey=api_key)

# %%
from pprint import pprint

# %%
def get_channel_details(c_id):
  request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=c_id
    )
  response = request.execute()

  data = {"channel_name" : response['items'][0]['snippet']['title'],
          "published_at" : response['items'][0]['snippet']['publishedAt'],
          "p_id" : response['items'][0]['contentDetails']['relatedPlaylists']['uploads'],
          "sub_count" : response['items'][0]['statistics']['subscriberCount'],
          "video_count" : response['items'][0]['statistics']['videoCount'],
          "view_count" : response['items'][0]['statistics']['viewCount']}
  return data

# %%
get_channel_details('UCueYcgdqos0_PzNOq81zAFg')
# Out:
# {'channel_name': 'Parithabangal',
#  'published_at': '2018-02-08T17:44:41Z',
#  'p_id': 'UUueYcgdqos0_PzNOq81zAFg',
#  'sub_count': '5380000',
#  'video_count': '778',
#  'view_count': '1302102826'}

# %%
channel_ids = ["UCJcCB-QYPIBcbKcBQOTwhiA", "UCueYcgdqos0_PzNOq81zAFg", "UCn4rEMqKtwBQ6-oEwbd4PcA"]
channel_details = []
for c_id in channel_ids:
  c_detail = get_channel_details(c_id)
  c_detail['channel_id'] = c_id
  channel_details.append(c_detail)

channel_details
# Out:
# [{'channel_name': 'Vj Siddhu Vlogs',
#   'published_at': '2023-06-14T07:41:42.139364Z',
#   'p_id': 'UUJcCB-QYPIBcbKcBQOTwhiA',
#   'sub_count': '2170000',
#   'video_count': '161',
#   'view_count': '312776806',
#   'channel_id': 'UCJcCB-QYPIBcbKcBQOTwhiA'},
#  {'channel_name': 'Parithabangal',
#   'published_at': '2018-02-08T17:44:41Z',
#   'p_id': 'UUueYcgdqos0_PzNOq81zAFg',
#   'sub_count': '5380000',
#   'video_count': '778',
#   'view_count': '1302102826',
#   'channel_id': 'UCueYcgdqos0_PzNOq81zAFg'},
#  {'channel_name': 'Sony Music South',
#   'published_at': '2014-08-06T15:11:11Z',
#   'p_id': 'UUn4rEMqKtwBQ6-oEwbd4PcA',
#   'sub_count': '17000000',
#   'video_count': '3396',
#   'view_count': '12126351306',
#   'channel_id': 'UCn4rEMqKtwBQ6-oEwbd4PcA'}]

# %%
def get_comment_details(video_id):
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=50
    )
    response = request.execute()

    comments = []
    for item in response['items']:
       # print(item)
        comment_data = {
            "comment_id": item['id'],
            "video_id": item['snippet']['videoId'],
            "comment_text": item['snippet']['topLevelComment']['snippet']['textOriginal'],
            "comment_author": item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
            "comment_published_At": item['snippet']['topLevelComment']['snippet']['publishedAt']
        }
        comments.append(comment_data)
    return comments

# %%
def extract_iso_time(dur):
    dur = dur[2:]
    h = dur.find('H')
    m = dur.find('M')
    s = dur.find('Y')
    hours, minutes, seconds = 0, 0, 0
    if h >= 0:
        hours = dur[:h]
    if m >= 0:
        minutes = dur[h+1:m]
    if s >= 0:
      seconds = dur[m+1:s]

    return (int(hours) * 3600) +  (int(minutes) * 60) + int(seconds)


extract_iso_time('PT1M')
# Out:
# 60

# %%
def get_video_details(v_id):
  request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=v_id
    )
  response = request.execute()
  # pprint(response['items'][0])

  video_data = {"video_name" : response['items'][0]['snippet']['title'],
                "channel_id": response['items'][0]['snippet']['channelId'],
                "video_id" : response['items'][0]['id'],
                "public_At" : response['items'][0]['snippet']['publishedAt'],
                "comment_count" : response['items'][0]['statistics']['commentCount'],
                "favourite_count" : response['items'][0]['statistics']['favoriteCount'],
                "like_count" : response['items'][0]['statistics']['likeCount'],
                "vid_view_count" : response['items'][0]['statistics']['viewCount'],
                "vid_duration": extract_iso_time(response['items'][0]['contentDetails']['duration']),
                "video_description" : response['items'][0]['snippet']['localized']['description']}
  return video_data

# %%
get_video_details('WcOm6gUN4DA')
# Out:
# {'video_name': 'எங்க தான்டா Ticket கிடைக்கும்!? #shorts | Parithabangal',
#  'channel_id': 'UCueYcgdqos0_PzNOq81zAFg',
#  'video_id': 'WcOm6gUN4DA',
#  'public_At': '2024-04-05T11:34:34Z',
#  'comment_count': '29',
#  'favourite_count': '0',
#  'like_count': '9474',
#  'vid_view_count': '115459',
#  'vid_duration': 60,
#  'video_description': '#parithabangal #shorts #paavangal #iplticketpaavangal #iplpaavangal #ipl \n\n________________________________\n\nStarring\n\nGO-SU\nhttps://www.instagram.com/gopi_aravindh\nhttps://www.instagram.com/duniya_sudhakar\nDravid Selvam: https://www.instagram.com/dravidselvam_6\n\n________________________________\n\nFollow our new channel : \nParithabangal Podcast  - https://www.youtube.com/channel/UCmMEMfmDJB-Ncx_C3WJ7ppg\n\nFollow Us On Social Media\n\nPARITHABANGAL \n\nFacebook    -  https://www.facebook.com/ParithabangalProductions/ \nInstagram   -  https://www.instagram.com/parithabangaloffl/?hl=en\nTwitter     -  https://twitter.com/Parithabangal_\nYoutube     -  https://www.youtube.com/channel/UCueYcgdqos0_PzNOq81zAFg   \n___________________________________\n\nIn Association with Divo :\nWebsite   - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook  - http://www.facebook.com/divomovies\nTwitter   - https://twitter.com/divomovies\n_____________________________________'}

# %%
def get_videos_for_channel(channel, count=50):

    request = youtube.playlistItems().list(
        part='contentDetails',
        maxResults=count,
        playlistId=channel['p_id']
      )
    response = request.execute()
    video_ids=[]
    videos=[]
    for item in response['items'][1:]:
        print(item)
        video_id = item['contentDetails']['videoId']
        video_ids.append(video_id)
        video_details = get_video_details(video_id)
        video_details['comments'] = get_comment_details(video_id)
        videos.append(video_details)
        video_details.update(channel)
    return videos

videos = []
for channel in channel_details:
  # print(channel['p_id'])
  videos.extend(get_videos_for_channel(channel))

len(videos)
# Out:
# {'kind': 'youtube#playlistItem', 'etag': 'weLtl7Oc8KEwZ2VAo1aqlMKQWoA', 'id': 'VVVKY0NCLVFZUElCY2JLY0JRT1R3aGlBLnlTY1YtWXdUbkVr', 'contentDetails': {'videoId': 'yScV-YwTnEk', 'videoPublishedAt': '2024-04-10T11:15:07Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'tPFmgpQz-qgBvp8uOutFcCm04y8', 'id': 'VVVKY0NCLVFZUElCY2JLY0JRT1R3aGlBL
 'id': 'VVVuNHJFTXFLdHdCUTYtb0V3YmQ0UGNBLnQzTjBqWkRBbkU4', 'contentDetails': {'videoId': 't3N0jZDAnE8', 'videoPublishedAt': '2024-03-26T18:30:42Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'b87jBmoevAvtKiehLsYR0szNCl0', 'id': 'VVVuNHJFTXFLdHdCUTYtb0V3YmQ0UGNBLnQzd0h5UkV4WGQ0', 'contentDetails': {'videoId': 't3wHyRExXd4', 'videoPublishedAt': '2024-03-26T18:30:42Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'Vfw2yg6h3uw18xzHgkohdg--q1U', 'id': 'VVVuNHJFTXFLdHdCUTYtb0V3YmQ0UGNBLnNoZldscXk0Tk5j', 'contentDetails': {'videoId': 'shfWlqy4NNc', 'videoPublishedAt': '2024-03-26T18:30:41Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'C3PAjdQWyivKtH4s-19BIji48fg', 'id': 'VVVuNHJFTXFLdHdCUTYtb0V3YmQ0UGNBLm9UM2VZZTRDMW84', 'contentDetails': {'videoId': 'oT3eYe4C1o8', 'videoPublishedAt': '2024-03-26T18:30:38Z'}}
# {'kind': 'youtube#playlistItem', 'etag': 'BAiONdLtkE8CisQMUYruK-7CzMU', 'id': 'VVVuNHJFTXFLdHdCUTYtb0V3YmQ0UGNBLmhBaC1TRS1fSG5z', 'contentDetails': {'videoId': 'hAh-SE-_Hns', 'videoPublishedAt': '2024-03-26T18:30:27Z'}}
# 147

# %%
get_video_details('hAh-SE-_Hns')
# Out:
# {'video_name': 'Mazhavillu Malayalam Songs Jukebox | Mohan Sithara | Kunchako Boban, Vineeth, Preeti Jhangiani',
#  'channel_id': 'UCn4rEMqKtwBQ6-oEwbd4PcA',
#  'video_id': 'hAh-SE-_Hns',
#  'public_At': '2024-03-26T18:30:27Z',
#  'comment_count': '0',
#  'favourite_count': '0',
#  'like_count': '7',
#  'vid_view_count': '743',
#  'vid_duration': 3060,
#  'video_description': 'Music Label - Sony Music Entertainment India Pvt. Ltd.\n\n© 2023 Sony Music Entertainment India Pvt. Ltd.\n\nSubscribe Now: http://bit.ly/SonyMusicSouthVevo\nSubscribe Now: http://bit.ly/SonyMusicSouthYT\nFollow us: https://www.instagram.com/sonymusic_south/\nFollow us: Twitter: https://twitter.com/SonyMusicSouth\nLike us: Facebook: https://www.facebook.com/SonyMusicSouth\nJoin our WhatsApp broadcast channel https://whatsapp.com/channel/0029VaAThD53GJOwZNFUJZ3B\nJoin Our Instagram broadcast channel https://ig.me/j/Abal-auA3Y5L6OtV/'}

# %%
from pymongo import MongoClient
connection = MongoClient("mongodb+srv://yuvarajs:guvi2024@cluster0.bk244m9.mongodb.net/")
db = connection.youtube
collection = db.video_details
#collection.insert_many(videos)

# %%
result = collection.find({})
result = list(result)

channel_table = []
comments_table = []
videos_table = []

for channel in channel_details:
  keys = ['channel_name', 'channel_id', 'published_at', 'p_id', 'sub_count', 'video_count','view_count']
  channel_table.append([channel[key] for key in keys])

for video in videos:
  keys = ['video_id', 'channel_id', 'video_name', 'public_At', 'comment_count', 'favourite_count', 'like_count' , 'vid_view_count', 'vid_duration','video_description']
  videos_table.append([video[key] for key in keys])
  for comment in video['comments']:
    comment_keys = ['comment_id', 'video_id', 'comment_text', 'comment_author', 'comment_published_At']
    comments_table.append([comment[key] for key in comment_keys])

# %%
import pandas as pd
import sqlite3
con = sqlite3.connect("youtube_Details.db")
cur = con.cursor()

# %%
def create_video_table(curr, drop=False):
  if drop:
    curr.execute("drop table if exists videos")
  curr.execute("CREATE TABLE videos(video_id, channel_id, video_name, public_At, comment_count INTEGER, favourite_count INTEGER, like_count INTEGER, vid_view_count INTEGER,vid_duration INTEGER,video_description) ")

def create_comments_table(curr, drop=False):
    if drop:
      curr.execute("drop table if exists comments")
    curr.execute("CREATE TABLE comments(comment_id, video_id, comment_text, comment_author, comment_published_At) ")

def create_channels_table(curr, drop=False):
    if drop:
      curr.execute("drop table if exists channels")
    curr.execute("CREATE TABLE channels(channel_name, channel_id, published_at, p_id, sub_count INTEGER, video_count INTEGER,view_count INTEGER) ")

# create_video_table(cur, drop=False)
# create_comments_table(cur, drop=False)
# create_channels_table(cur, drop=False)

# %%
def insert_videos(curr, videos):
  curr.executemany ("""INSERT INTO videos(video_id, channel_id, video_name, public_At, comment_count, favourite_count, like_count, vid_view_count, vid_duration, video_description)
                                 VALUES (?,?,?,?,?,?,?,?,?,?)""" , videos)

def insert_comments(curr, comments):
  curr.executemany("""INSERT INTO comments(comment_id, video_id, comment_text, comment_author, comment_published_At) VALUES (?,?,?,?,?)""", comments)

def insert_channels(curr, channels):
  curr.executemany("""INSERT INTO channels(channel_name, channel_id, published_at, p_id, sub_count, video_count,view_count) VALUES (?, ?, ?, ?, ?, ?, ?)""", channels)

# %%
# from pickle import TRUE
insert_videos(cur, videos_table)
insert_comments(cur, comments_table)
insert_channels(cur, channel_table)

# %%
Table_name=pd.read_sql_query('''SELECT name FROM sqlite_master WHERE type = 'table' AND name NOT LIKE 'sqlite_%';''',con )

# %%
print("Total Tables are:",len(Table_name))
print("*"*20)
# Out:
# Total Tables are: 3
# ********************

# %%
pd.read_sql_query('select * from videos order by vid_view_count desc limit 20', con)
# Out:
#        video_id                channel_id  \
# 0   QIGYf2erUHo  UCJcCB-QYPIBcbKcBQOTwhiA
# 1   zcaOimCOsmQ  UCJcCB-QYPIBcbKcBQOTwhiA
# 2   EQKYyL6ycSM  UCJcCB-QYPIBcbKcBQOTwhiA
# 3   EUeu-GJyuYw  UCJcCB-QYPIBcbKcBQOTwhiA
# 4   s5RDMG_tUao  UCJcCB-QYPIBcbKcBQOTwhiA
# 5   XGJtiqVzZiA  UCn4rEMqKtwBQ6-oEwbd4PcA
# 6   L9W6yPDOILE  UCueYcgdqos0_PzNOq81zAFg
# 7   tLMoqfR-qCQ  UCJcCB-QYPIBcbKcBQOTwhiA
# 8   YrXAUN3p1IM  UCJcCB-QYPIBcbKcBQOTwhiA
# 9   ZoI2wfj_OX0  UCJcCB-QYPIBcbKcBQOTwhiA
# 10  NPMjsLOPN70  UCJcCB-QYPIBcbKcBQOTwhiA
# 11  4NppfA06-_s  UCJcCB-QYPIBcbKcBQOTwhiA
# 12  FV9xIo7Umlg  UCJcCB-QYPIBcbKcBQOTwhiA
# 13  3q6-_eROVDA  UCJcCB-QYPIBcbKcBQOTwhiA
# 14  EKyT8SVo89s  UCJcCB-QYPIBcbKcBQOTwhiA
# 15  oVHwoZaMD-s  UCJcCB-QYPIBcbKcBQOTwhiA
# 16  6l55q7r4MGU  UCJcCB-QYPIBcbKcBQOTwhiA
# 146  Mazhavillu Malayalam Songs Jukebox | Mohan Sit...  2024-03-26T18:30:27Z
#
#      comment_count  favourite_count  like_count  vid_view_count  vid_duration  \
# 0             2288                0      159751         1984899          1380
# 1             1759                0      164360         2303478          1740
# 2             1110                0      143820         1975192          1140
# 3             1074                0      152909         2162053          1200
# 4             1185                0      147227         1797571          1200
# ..             ...              ...         ...             ...           ...
# 142              5                0         113           15165         10500
# 143              1                0          10             540          1980
# 144              1                0           2             403          3360
# 145              0                0           5             360          1560
# 146              0                0           7             743          3060
#
#                                      video_description
# 0    GT Holidays:\nContact GT holidays for Tour Pac...
# 1    For Business inquiries please contact us :7200...
# 2    For Business inquiries please contact us :7200...
# 3    For Business inquiries please contact us :7200...
# 4    For Business inquiries please contact us :7200...
# ..                                                 ...
# 142  Perilla Raajyathe\nMaanthalirin Pattu Chuttiya...
# 143  Music Label - Sony Music Entertainment India P...
# 144  Music Label - Sony Music Entertainment India P...
# 145  Music Label - Sony Music Entertainment India P...
# 146  Music Label - Sony Music Entertainment India P...
#
# [147 rows x 10 columns]

# %% [markdown]
# Query:1 What are the names of all the videos and their corresponding channels?

# %%
Query1 = pd.read_sql_query('SELECT channel_name,video_name FROM videos v JOIN channels c on v.channel_id = c.channel_id ',con)
Query1.head(10)
# Out:
#       channel_name                                         video_name
# 0  Vj Siddhu Vlogs  குரங்குக்கே Love Failure-ஆ😱| Dubai Series EP -...
# 1  Vj Siddhu Vlogs  நாங்க செய்றது தான் சமையல் | Dubai Series EP-9 ...
# 2  Vj Siddhu Vlogs  ஒட்டகம் வாங்கப் போறோம் 😍😋 | Dubai Series EP 8 ...
# 3  Vj Siddhu Vlogs  Super Man-அ பாத்துட்டோம் 😱🔥 |  Dubai Series EP...
# 4  Vj Siddhu Vlogs  Rugged Boy-ஆ நீங்க 😱🤙🏻| GV Prakash| Vj Siddhu ...
# 5  Vj Siddhu Vlogs  இவனுங்கள நம்புனா இப்டி தான் 😫 Dubai Series EP ...
# 6  Vj Siddhu Vlogs  எப்போபா Theme Park போறோம் 😕🥺  | Dubai Series E...
# 7  Vj Siddhu Vlogs  Theme Park போறோம் 😍  | Dubai Series EP 4 | Vj ...
# 8  Vj Siddhu Vlogs  Sorry இனியாழ்🥹 | Dubai Series EP 3 | Vj Siddhu...
# 9  Vj Siddhu Vlogs  Direction விட Acting ஜாலியா இருக்கு 😜 | Vj Sid...

# %% [markdown]
# Query:2
# Which channels have the most number of videos, and how many videos do
#  they have?

# %%
Query2 = pd.read_sql_query('SELECT channel_name, max(video_count) from channels' ,con)
Query2

# %% [markdown]
# Query:3 What are the top 10 most viewed videos and their respective channels?

# %%
Query3 = pd.read_sql_query('SELECT channel_name, video_name,vid_view_count FROM videos v JOIN channels c on v.channel_id = c.channel_id order by vid_view_count desc limit 10 ',con)
Query3

# %% [markdown]
# Query:4 How many comments were made on each video, and what are their corresponding video names?

# %%
Query4 = pd.read_sql_query('SELECT video_name, comment_count FROM videos',con)
Query4

# %% [markdown]
# Query:5 Which videos have the highest number of likes, and what are their corresponding channel names?

# %%
Query5 = pd.read_sql_query('SELECT channel_name, video_name, like_count FROM videos v JOIN channels c on v.channel_id = c.channel_id  ORDER BY like_count DESC LIMIT 10',con)
Query5
# Out:
#       channel_name                                         video_name  \
# 0  Vj Siddhu Vlogs  வானத்துல Cake வெட்றோம் 🥳🤩 | Sri Lanka EP01 | V...
# 1  Vj Siddhu Vlogs  மாட்டுனடா பம்பரகட்ட மண்டையா 🤣🔥 | Insta series ...
# 2  Vj Siddhu Vlogs  அப்பா hospital - ல இருக்காரு 😥 | insta series ...
# 3  Vj Siddhu Vlogs  நான் தான் டா Riya Kannan🤣💥 | insta series epi ...
# 4  Vj Siddhu Vlogs  தல Dhoni- க்கு call பண்ணுங்க😎 | Ft. Rj Balaji ...
# 5  Vj Siddhu Vlogs  Welcome to Ini vlogs | Dubai Series Ep 01 | Vj...
# 6  Vj Siddhu Vlogs  உன்ன பாத்தா எனக்கு கேன பையனு தோணுது😂😱 | Ft.Vij...
# 7  Vj Siddhu Vlogs  Love Torture பண்றான் டா😔  | insta series epi -...
# 8  Vj Siddhu Vlogs  எல்லாருமே ஒற்றுமையா இருக்கீங்க🥰❤️ | Sri Lanka ...
# 9  Vj Siddhu Vlogs  தலைவர் படத்துல நடிக்க போறோம் 😍🔥 | Lokesh Kanag...
#
#    like_count
# 0      249428
# 1      244108
# 2      236940
# 3      232699
# 4      214945
# 5      201749
# 6      201526
# 7      198952
# 8      194447
# 9      192891

# %% [markdown]
# Query:6 What is the total number of likes and dislikes for each video, and what are their corresponding video names?

# %%
Query6 = pd.read_sql_query('SELECT video_name,like_count FROM videos',con)
Query6
# Out:
#                                             video_name  like_count
# 0    குரங்குக்கே Love Failure-ஆ😱| Dubai Series EP -...      152740
# 1    நாங்க செய்றது தான் சமையல் | Dubai Series EP-9 ...      161323
# 2    ஒட்டகம் வாங்கப் போறோம் 😍😋 | Dubai Series EP 8 ...      142419
# 3    Super Man-அ பாத்துட்டோம் 😱🔥 |  Dubai Series EP...      151919
# 4    Rugged Boy-ஆ நீங்க 😱🤙🏻| GV Prakash| Vj Siddhu ...      146755
# ..                                                 ...         ...
# 142  All Time Love Hits Malayalam Vol.2 Malayalam S...         111
# 143  Mayilppeelikkavu Malayalam Songs Jukebox | Ber...          10
# 144           Bharatanatya Gaanangal Malayalam Jukebox           2
# 145  Mayapponman Malayalam Songs Jukebox | Mohan Si...           4
# 146  Mazhavillu Malayalam Songs Jukebox | Mohan Sit...           5
#
# [147 rows x 2 columns]

# %% [markdown]
# Query:7 What is the total number of views for each channel, and what are their corresponding channel names?

# %%
Query7 = pd.read_sql_query('SELECT channel_name,video_name,like_count FROM videos JOIN channels ORDER BY like_count DESC LIMIT 10',con)
Query7
# Out:
#        channel_name                                         video_name  \
# 0   Vj Siddhu Vlogs  வானத்துல Cake வெட்றோம் 🥳🤩 | Sri Lanka EP01 | V...
# 1     Parithabangal  வானத்துல Cake வெட்றோம் 🥳🤩 | Sri Lanka EP01 | V...
# 2  Sony Music South  வானத்துல Cake வெட்றோம் 🥳🤩 | Sri Lanka EP01 | V...
# 3   Vj Siddhu Vlogs  மாட்டுனடா பம்பரகட்ட மண்டையா 🤣🔥 | Insta series ...
# 4     Parithabangal  மாட்டுனடா பம்பரகட்ட மண்டையா 🤣🔥 | Insta series ...
# 5  Sony Music South  மாட்டுனடா பம்பரகட்ட மண்டையா 🤣🔥 | Insta series ...
# 6   Vj Siddhu Vlogs  அப்பா hospital - ல இருக்காரு 😥 | insta series ...
# 7     Parithabangal  அப்பா hospital - ல இருக்காரு 😥 | insta series ...
# 8  Sony Music South  அப்பா hospital - ல இருக்காரு 😥 | insta series ...
# 9   Vj Siddhu Vlogs  நான் தான் டா Riya Kannan🤣💥 | insta series epi ...
#
#    like_count
# 0      249428
# 1      249428
# 2      249428
# 3      244108
# 4      244108
# 5      244108
# 6      236940
# 7      236940
# 8      236940
# 9      232699

# %% [markdown]
#  Query:8 What are the names of all the channels that have published videos in the year 2022?

# %%
Query8 = pd.read_sql_query("SELECT channel_name,public_At FROM videos v JOIN channels c on v.channel_id = c.channel_id",con)
Query8['public_At'] = pd.to_datetime(Query8['public_At'])
#--------------------

mask = Query8['public_At'].dt.year == int(2024)
Query8 = Query8[mask]
Query8
# Out:
#          channel_name                 public_At
# 0     Vj Siddhu Vlogs 2024-04-10 11:15:07+00:00
# 1     Vj Siddhu Vlogs 2024-04-08 09:30:08+00:00
# 2     Vj Siddhu Vlogs 2024-04-07 04:30:08+00:00
# 3     Vj Siddhu Vlogs 2024-04-05 09:30:08+00:00
# 4     Vj Siddhu Vlogs 2024-04-03 09:30:08+00:00
# ..                ...                       ...
# 142  Sony Music South 2024-03-26 18:30:42+00:00
# 143  Sony Music South 2024-03-26 18:30:42+00:00
# 144  Sony Music South 2024-03-26 18:30:41+00:00
# 145  Sony Music South 2024-03-26 18:30:38+00:00
# 146  Sony Music South 2024-03-26 18:30:27+00:00
#
# [147 rows x 2 columns]

# %% [markdown]
# Query:9 What is the average duration of all videos in each channel, and what are their corresponding channel names?

# %%
Query9 = pd.read_sql_query('SELECT channel_name, avg(vid_duration) FROM videos v JOIN channels c on v.channel_id = c.channel_id group by channel_name',con)
Query9
# Out:
#        channel_name  avg(vid_duration)
# 0     Parithabangal         277.959184
# 1  Sony Music South        1070.204082
# 2   Vj Siddhu Vlogs        1455.918367

# %% [markdown]
#  Query:10 Which videos have the highest number of comments, and what are their corresponding channel names?

# %%
Query10= pd.read_sql_query('SELECT channel_name,comment_count FROM videos v JOIN channels c on v.channel_id = c.channel_id order by comment_count desc limit 20',con)
Query10
# Out:
#        channel_name  comment_count
# 0   Vj Siddhu Vlogs          10448
# 1   Vj Siddhu Vlogs           6542
# 2   Vj Siddhu Vlogs           5784
# 3   Vj Siddhu Vlogs           5372
# 4   Vj Siddhu Vlogs           4728
# 5   Vj Siddhu Vlogs           4068
# 6   Vj Siddhu Vlogs           3642
# 7   Vj Siddhu Vlogs           3440
# 8   Vj Siddhu Vlogs           3225
# 9   Vj Siddhu Vlogs           3158
# 10  Vj Siddhu Vlogs           3132
# 11  Vj Siddhu Vlogs           2962
# 12    Parithabangal           2917
# 13  Vj Siddhu Vlogs           2897
# 14  Vj Siddhu Vlogs           2879
# 15  Vj Siddhu Vlogs           2853
# 16    Parithabangal           2778
# 17  Vj Siddhu Vlogs           2741
# 18  Vj Siddhu Vlogs           2632
# 19  Vj Siddhu Vlogs           2599
